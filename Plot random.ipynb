# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import csv
data = []

with open("group rand.csv") as result:
    reader = csv.reader(result)
    skip_first = True
    for row in reader:
        if skip_first:
            skip_first = False
            continue
        if len(row) > 0:
            data.append(row)

# %%
import numpy as np
data = np.array(data)

# %%
empty_dist = list(map(float, data[:, 2]))
not_empty_dist = list(map(float, data[:, 5]))

# %%
plt.plot(range(500), empty_dist, 'b', range(500), not_empty_dist, 'r')
plt.show()
